# %% [markdown]
# # Testing for CamelUp Algorithm
# ### import of code

# %%
# %load_ext autoreload
# %autoreload 2

from CamelUp import *

# %% [markdown]
# ### precompile njit functions:

# %%
"""
demo_players = {"Player 1":player("Player 1"),"Player 2":player("Player 2"),
                "Player 3":player("Player 3"),"Player 4":player("Player 4")}
demo_precompilation = Field([
    [], [], [], [], [], ['Yellow', 'Green'], ['Purple', 'Blue', 'Orange'], ["DESERT", "Player 1"], [], 
    ["Black", "White"], [], [], [], [],[], [], [], [], []],copy.deepcopy(demo_players))
n_camels_thrown = 4
camels_not_thrown = [1,2]
game_inventory_matrix = np.array([[1,1,2]]*5)
rendered_field, inv_player_mask = render_field(demo_precompilation.game_field,demo_precompilation.players)
positions, DO_hits, VOI = sim_all_moves(rendered_field, 4, n_camels_thrown, camels_not_thrown, game_inventory_matrix, verbose=False)
positions, DO_hits, VOI
"""
print()
# Out:
# (array([[0.16666667, 0.        , 0.83333333],
#         [0.        , 0.83333333, 0.16666667],
#         [0.83333333, 0.16666667, 0.        ],
#         [0.        , 0.        , 1.        ],
#         [0.        , 0.        , 1.        ]]),
#  array([[0.33333333],
#         [0.        ],
#         [0.        ],
#         [0.        ]]),
#  5.333333333333335)

# %% [markdown]
# ### Some base field 4 players

# %%
demo_players = {"Player 1":player("Player 1"),"Player 2":player("Player 2"),
                "Player 3":player("Player 3"),"Player 4":player("Player 4")}
demoE = Field([
    [], [], [], [], [], ['Yellow', 'Green'], ['Purple', 'Blue', 'Orange'], [], [], 
    ["Black", "White"], [], [], [], [],[], [], [], [], []],copy.deepcopy(demo_players))

# %%
## Init function with pre-defined players and game field
Test_0_1 = CamelUp(4,field = demoE,black_white=True,user_guide=True)
# Out:
# ————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# [41, 126]
#
#                                            #####################
#                                            ##  Current Field  ##
#                                            #####################
#
#      ════════════════════════════════════════════════════════════════════════════════════════════════════════════════════
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ════════════════════════════════════════════════════════════════════════════════════════════════════════════════════
#      ║                      ║                                                                    ║                      ║
#      ║                      ║             <16>               < 1>               < 2>             ║                      ║
#      ║                      ║     <15>                                                  < 3>     ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║   <14>                                                      < 4>   ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ════════════════════════                                                                    ════════════════════════
#      ║                      ║                                                                    ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║                ═══════════════════════════════════                 ║                      ║
#      ║                      ║   <13>         ║ Value of Information:     0.000 ║          < 5>   ║                      ║
#      ║                      ║                ═══════════════════════════════════                 ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ════════════════════════                                                                    ════════════════════════
#      ║                      ║                                                                    ║        Yellow        ║
#      ║                      ║   <12>                                                      < 6>   ║        Green         ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║     <11>                                                  < 7>     ║                      ║
#      ║                      ║             <10>               < 9>               < 8>             ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ════════════════════════════════════════════════════════════════════════════════════════════════════════════════════
#      ║                      ║        Black         ║                      ║                      ║        Purple        ║
#      ║                      ║        White         ║                      ║                      ║         Blue         ║
#      ║                      ║                      ║                      ║                      ║        Orange        ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ════════════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# #######################
# #  Coins of players:  #
# #######################
#
#      Players   Player 1   Player 2   Player 3   Player 4
#      Coins     3          3          3          3
#      EV        0          0          0          0
# ————————————————————————————————————————————————————————————————————————————————————————————————————————————————————

# %%
## caution: starts game!
Test_0_1.game()
# Out:
# ###################
# #  Start Player?  #
# ###################
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[32], line 2
#       1 ## caution: starts game!
# ----> 2 Test_0_1.game()
#
# File c:\Users\eikeb\OneDrive\Dokumente\GitHub\CamelUp\CamelUp.py:816, in CamelUp.game(self, player)
#     814 while self.game_not_end():
#     815     player = list(self.players.keys())[index%n_players]
# --> 816     self.make_a_move(player)
#     817     if len(self.moved) == 5:
#     818         self.cl() #end of round function
#
# File c:\Users\eikeb\OneDrive\Dokumente\GitHub\CamelUp\CamelUp.py:944, in CamelUp.make_a_move(self, player)
#     942     if i not in self.moved:
#     943         CNM+=print_adj(i,8,"l")+", "
# --> 944 self.one_turn(print_option=False,OD=True,player=player)
#     945 self.print_game(True, True) # prints game with field and payoffs and player gains
#     946 self.print_i()
#
# File c:\Users\eikeb\OneDrive\Dokumente\GitHub\CamelUp\CamelUp.py:644, in CamelUp.one_turn(self, print_option, OD, player)
#     641 ## Oasis and Desert value optimisation.
#     642 if OD:
#     643     ## calculate desert value for player for all legal fields:
# --> 644     fields_payoffs = self._desert_iterator(player)
#     645     ## returns a dictionary of payoffs
#     646
#     647     ## delta base is the expected payoff of the player's plate at the start of the turn.
#     648     delta_base = self.base_DO_hits[player_index]
#
# File c:\Users\eikeb\OneDrive\Dokumente\GitHub\CamelUp\CamelUp.py:761, in CamelUp._desert_iterator(self, player)
#     759 fields_payoffs = {}
#     760 for i in fields.keys():
# --> 761     fields_payoffs[i] = sim_all_moves(fields[i],len(start_players),n_camels_thrown,Camels_die,self.game_inventory_matrix)
#     763 return fields_payoffs
#
# File c:\Users\eikeb\Anaconda3\Lib\site-packages\numba\core\dispatcher.py:468, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     464         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     465                f"by the following argument(s):\n{args_str}\n")
#     466         e.patch_message(msg)
# --> 468     error_rewrite(e, 'typing')
#     469 except errors.UnsupportedError as e:
#     470     # Something unsupported is present in the user code, add help info
#     471     error_rewrite(e, 'unsupported_error')
#
# File c:\Users\eikeb\Anaconda3\Lib\site-packages\numba\core\dispatcher.py:409, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     407     raise e
#     408 else:
# --> 409     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# non-precise type pyobject
# During: typing of argument at c:\Users\eikeb\OneDrive\Dokumente\GitHub\CamelUp\CamelUp.py (1161)
#
# File "CamelUp.py", line 1161:
# def format_tables(probabilities: pd.DataFrame, payoffs: pd.DataFrame, game_inventory_list: list = [],extended: bool = False) -> str:
#     <source elided>
# @nb.njit(cache=True, parallel=True)
# #@nb.njit(parallel=True)
# ^
#
# This error may have been caused by the following argument(s):
# - argument 4: Cannot determine Numba type of <class 'method'>

# %%
print("12"+f"{1234567890:10.3f}"+"12")
# Out:
# 121234567890.00012
