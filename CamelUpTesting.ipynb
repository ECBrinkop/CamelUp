# %% [markdown]
# # Testing for CamelUp Algorithm
# ### import of code

# %%
# %load_ext autoreload
# %autoreload 2

from CamelUp import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### precompile njit functions:

# %%
demo_players = {"Player 1":player("Player 1"),"Player 2":player("Player 2"),
                "Player 3":player("Player 3"),"Player 4":player("Player 4")}
demo_precompilation = Field([
    [], [], [], [], [], ['Yellow', 'Green'], ['Purple', 'Blue', 'Orange'], ["DESERT", "Player 1"], [], 
    ["Black", "White"], [], [], [], [],[], [], [], [], []],copy.deepcopy(demo_players))
n_camels_thrown = 4
camels_not_thrown = [1,2]
game_inventory_matrix = np.array([[1,1,2]]*5)
rendered_field, inv_player_mask = render_field(demo_precompilation.game_field,demo_precompilation.players)
positions, DO_hits, VOI = sim_all_moves(rendered_field, 4, n_camels_thrown, camels_not_thrown, game_inventory_matrix, verbose=False)
positions, DO_hits, VOI
# Out:
# (array([[0.16666667, 0.        , 0.83333333],
#         [0.        , 0.83333333, 0.16666667],
#         [0.83333333, 0.16666667, 0.        ],
#         [0.        , 0.        , 1.        ],
#         [0.        , 0.        , 1.        ]]),
#  array([[0.33333333],
#         [0.        ],
#         [0.        ],
#         [0.        ]]),
#  5.333333333333335)

# %% [markdown]
# ### Some base field 4 players

# %%
demo_players = {"Player 1":player("Player 1"),"Player 2":player("Player 2"),
                "Player 3":player("Player 3"),"Player 4":player("Player 4")}
demoE = Field([
    [], [], [], [], [], ['Yellow', 'Green'], ['Purple', 'Blue', 'Orange'], [], [], 
    ["Black", "White"], [], [], [], [],[], [], [], [], []],copy.deepcopy(demo_players))

# %%
## Init function with pre-defined players and game field
Test_0_1 = CamelUp(4,field = demoE,black_white=True,user_guide=True)
# Out:
# ————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# [41, 126]
#
#                                            #####################
#                                            ##  Current Field  ##
#                                            #####################
#
#      ════════════════════════════════════════════════════════════════════════════════════════════════════════════════════
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ════════════════════════════════════════════════════════════════════════════════════════════════════════════════════
#      ║                      ║                                                                    ║                      ║
#      ║                      ║             <16>               < 1>               < 2>             ║                      ║
#      ║                      ║     <15>                                                  < 3>     ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║   <14>                                                      < 4>   ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ════════════════════════                                                                    ════════════════════════
#      ║                      ║                                                                    ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║                ═══════════════════════════════════                 ║                      ║
#      ║                      ║   <13>         ║ Value of Information:     0.000 ║          < 5>   ║                      ║
#      ║                      ║                ═══════════════════════════════════                 ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ════════════════════════                                                                    ════════════════════════
#      ║                      ║                                                                    ║        Yellow        ║
#      ║                      ║   <12>                                                      < 6>   ║        Green         ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ║                      ║     <11>                                                  < 7>     ║                      ║
#      ║                      ║             <10>               < 9>               < 8>             ║                      ║
#      ║                      ║                                                                    ║                      ║
#      ════════════════════════════════════════════════════════════════════════════════════════════════════════════════════
#      ║                      ║        Black         ║                      ║                      ║        Purple        ║
#      ║                      ║        White         ║                      ║                      ║         Blue         ║
#      ║                      ║                      ║                      ║                      ║        Orange        ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ║                      ║                      ║                      ║                      ║                      ║
#      ════════════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# #######################
# #  Coins of players:  #
# #######################
#
#      Players   Player 1   Player 2   Player 3   Player 4
#      Coins     3          3          3          3
#      EV        0          0          0          0
# ————————————————————————————————————————————————————————————————————————————————————————————————————————————————————

# %%
## caution: starts game!
Test_0_1.game()
# Out:
# ###################
# #  Start Player?  #
# ###################
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 ## caution: starts game!
# ----> 2 Test_0_1.game()
#
# File c:\Users\eikeb\OneDrive\Dokumente\GitHub\CamelUp\CamelUp.py:815, in CamelUp.game(self, player)
#     813 while self.game_not_end():
#     814     player = list(self.players.keys())[index%n_players]
# --> 815     self.make_a_move(player)
#     816     if len(self.moved) == 5:
#     817         self.cl() #end of round function
#
# File c:\Users\eikeb\OneDrive\Dokumente\GitHub\CamelUp\CamelUp.py:943, in CamelUp.make_a_move(self, player)
#     941     if i not in self.moved:
#     942         CNM+=print_adj(i,8,"l")+", "
# --> 943 self.one_turn(print_option=False,OD=True,player=player)
#     944 self.print_game(True, True) # prints game with field and payoffs and player gains
#     945 self.print_i()
#
# File c:\Users\eikeb\OneDrive\Dokumente\GitHub\CamelUp\CamelUp.py:582, in CamelUp.one_turn(self, print_option, OD, player)
#     580 start_field = copy.deepcopy(self.game_field)
#     581 ## render said field
# --> 582 rendered_field, player_mapping = render_field(self.game_field)
#     584 ## render game inventory matrix
#     585 game_inventory_matrix = self.game_inventory_matrix(self.game_inventory)
#
# File c:\Users\eikeb\OneDrive\Dokumente\GitHub\CamelUp\CamelUp.py:1033, in render_field(field)
#    1032 def render_field(field:Field):
# -> 1033     player_mask = {name: i+10 for i, name in enumerate(field.players.keys())}
#    1034     mask = CamelUp.mask
#    1035     mask["DESERT"] = 8
#
# AttributeError: 'list' object has no attribute 'players'

# %%
print("12"+f"{1234567890:10.3f}"+"12")
# Out:
# 121234567890.00012
